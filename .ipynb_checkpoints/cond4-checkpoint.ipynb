# %%
import sys
import torch
import importlib

# %matplotlib inline

sys.path.append('src')

import reversi

import numpy as np
import pylab as plt
import seaborn as sns
import time

#from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm
sns.set()

import deepPlayer
import qFunction
importlib.reload(qFunction)

from memory import Memory
from qFunction import QFunction

import pickle
import plot

from plot import plot_win_rate
from plot import test_and_plot_win_rate

importlib.reload(deepPlayer)
importlib.reload(plot)

#変更を加えたいファイルはreversiから出してreload(クラス名)をすればよい
# Out:
# /data/anaconda/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/anaconda/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <module 'plot' from '/data/home/intern/main/intern-summer-2019/plot.py'>

# %% [markdown]
# # train

# %%
day = "0910"
cond = 6

# %%
episode_num = 100
memory_size = 30 * episode_num
batch_size = 60

target_update = 5000

alpha = 0.2 #0でrandom experience replayと等価
beta = 0.7

memory = Memory(size = memory_size)
enemy_memory = Memory(size = memory_size)

eps_decrease = 1 / 10000

dqn_player = deepPlayer.DQNPlayer("どきゅん太郎", memory, eps_decrease = eps_decrease, alpha = alpha, batch_size=batch_size, 
                                  beta = beta, use_IS=False, PER=False, cond = cond)

enemy_dqn_player = deepPlayer.DQNPlayer("どきゅん敵太郎", enemy_memory, eps_decrease = eps_decrease, alpha = alpha, batch_size=batch_size, 
                                  beta = beta, use_IS=False, PER=False, cond = cond)


random_player = reversi.player.RandomPlayer("乱太郎")
# Out:
# DuelingDQN_3_6(
#   (fc1): Linear(in_features=64, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3_adv): Linear(in_features=256, out_features=64, bias=True)
#   (fc3_v): Linear(in_features=256, out_features=1, bias=True)
# )
# DuelingDQN_3_6(
#   (fc1): Linear(in_features=64, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3_adv): Linear(in_features=256, out_features=64, bias=True)
#   (fc3_v): Linear(in_features=256, out_features=1, bias=True)
# )

# %% [markdown]
# ## random

# %%
random_train_num = 40000


plot_train = True
plot_test = True

for i in tqdm(range(random_train_num)):
    if np.random.random() < 0.5:
        white = dqn_player
        black = enemy_dqn_player
    else:
        white = enemy_dqn_player
        black = dqn_player
    game = reversi.Reversi(white, black)
    game.main_loop(print_game = False)

    if batch_size <= dqn_player.memory.counter: #memory数がバッチサイズ以下の時は学習しない
        dqn_player.q_function.train()
        enemy_dqn_player.q_function.main_network.load_state_dict(dqn_player.q_function.main_network.state_dict())
        
    if i % target_update == 0:
        dqn_player.q_function.update_target_network()
        
    if plot_train and i % 999 == 0 and i != 0:
        #訓練時勝率をプロット
        plot_win_rate(dqn_player, save_name = "./fig/{0}_cond{1}/{0}_cond{1}_{2}_train.pdf".format(day, cond, i))
        
    if plot_test and i % 999 == 0 and i != 0:
        #epsilon=0にして評価用勝率をplot
        test_and_plot_win_rate(dqn_player, save_name = "./fig/{0}_cond{1}/{0}_cond{1}_{2}_train.pdf".format(day, cond, i))
# Out:
#   2%|▏         | 994/40000 [00:17<12:30, 51.98it/s]
# battle with random...
#   2%|▏         | 994/40000 [00:29<12:30, 51.98it/s]
#   5%|▍         | 1995/40000 [01:01<13:33, 46.74it/s]
# battle with random...
#   5%|▍         | 1995/40000 [01:20<13:33, 46.74it/s]
#   7%|▋         | 2996/40000 [01:48<15:33, 39.64it/s]
# battle with random...
#   7%|▋         | 2996/40000 [02:00<15:33, 39.64it/s]
#  10%|▉         | 3996/40000 [02:38<16:38, 36.05it/s]
# battle with random...
#  10%|▉         | 3996/40000 [02:50<16:38, 36.05it/s]
#  12%|█▏        | 4993/40000 [03:31<18:27, 31.62it/s]
# battle with random...
#  12%|█▏        | 4993/40000 [03:50<18:27, 31.62it/s]
#  15%|█▍        | 5994/40000 [04:28<19:50, 28.57it/s]
# battle with random...
#  15%|█▍        | 5994/40000 [04:40<19:50, 28.57it/s]
#  17%|█▋        | 6991/40000 [05:27<21:13, 25.91it/s]
# battle with random...
#  17%|█▋        | 6991/40000 [05:40<21:13, 25.91it/s]
#  20%|█▉        | 7990/40000 [06:31<22:27, 23.75it/s]
# battle with random...
#  20%|█▉        | 7990/40000 [06:50<22:27, 23.75it/s]
#  22%|██▏       | 8989/40000 [07:38<22:49, 22.64it/s]
# battle with random...
#  22%|██▏       | 8989/40000 [07:50<22:49, 22.64it/s]
#  25%|██▍       | 9990/40000 [08:48<23:26, 21.33it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c885fe3a3a8b> in <module>()
#      24     if plot_train and i % 999 == 0 and i != 0:
#      25         #訓練時勝率をプロット
# ---> 26         plot_win_rate(dqn_player, save_name = "./fig/con{}/con{}_{}_train.pdf".format(cond, cond, i))
#      27
#      28     if plot_test and i % 999 == 0 and i != 0:
#
# /data/home/intern/main/intern-summer-2019/plot.py in plot_win_rate(dqn_player, save_name)
#      24
#      25     plt.plot(np.cumsum(wining_DQN) / (np.arange(len(wining_DQN)) + 1))
# ---> 26     plt.savefig(save_name, bbox_inches="tight")
#      27     plt.show()
#      28
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2576             file = filename._file
#    2577         else:
# -> 2578             file = PdfFile(filename, metadata=kwargs.pop("metadata", None))
#    2579         try:
#    2580             file.newPage(width, height)
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     436         self.original_file_like = None
#     437         self.tell_base = 0
# --> 438         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     439         if not opened:
#     440             try:
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './fig/con6/con6_9990_train.pdf'
#  25%|██▍       | 9990/40000 [09:00<23:26, 21.33it/s]

# %% [raw]
# #pickleに保存
# with open("./pickle/sota.pickle", "wb") as f:
#     pickle.dump(dqn_player, f)

# %%
#replayの分布とlossの遷移を表示
plot.plot_dist_sample(dqn_player.q_function.ind_log)
plot.plot_loss(dqn_player.q_function.loss_log)

# %% [markdown]
# ## own

# %%
enemy_memory = Memory(size = memory_size)
enemy_dqn_player = deepPlayer.DQNPlayer("敵太郎", enemy_memory, eps_decrease = eps_decrease)

# %%
train_num = 5000

for i in tqdm(range(train_num)):
    if np.random.random() < 0.5:
        white = dqn_player
        black = enemy_dqn_player
    else:
        white = enemy_dqn_player
        black = dqn_player
    game = reversi.Reversi(white, black)
    game.main_loop(print_game = False)


    dqn_player.q_function.train()
    enemy_dqn_player.q_function.train()

# %%
wininig_DQN = np.array(dqn_player.record) == 1

plt.grid(True)
plt.ylim(0, 1)
plt.title("win_rate (Battle with same structure)")
plt.plot(np.cumsum(wininig_DQN) / (np.arange(len(wininig_DQN)) + 1))
plt.show()

# %% [markdown]
# # check win_rate(Battle with random)

# %%
# Out:
# 100%|██████████| 500/500 [00:09<00:00, 55.79it/s]

# %% [markdown]
# ## check enemy win rate
# 同じ構造のネットワークと訓練した時は相手のネットワークの勝率も一応確認

# %%
game_num = 2000

#train時レコードとepsilon退避
train_record = enemy_dqn_player.record
enemy_dqn_player.record = []

train_eps = enemy_dqn_player.eps
enemy_dqn_player.eps = 0 #greedy挙動のみ

train_memory = dqn_player.memory
dqn_player.memory = Memory(size=64)

for i in tqdm(range(game_num)):
    
    if np.random.random() < 0.5:
        white = random_player
        black = enemy_dqn_player
    else:
        white = enemy_dqn_player
        black = random_player
    game = reversi.Reversi(white, black)
    game.main_loop(print_game=False)
    


wining_DQN = np.array(enemy_dqn_player.record) == 1

plt.grid(True)
plt.ylim(0, 1)
final_win_rate = np.cumsum(wining_DQN)[len(np.cumsum(wining_DQN))-1]/len(wining_DQN)
plt.title("win_rate(Battle with random, final = {})".format(round(final_win_rate, 4)))
plt.xlabel("episode")
plt.ylabel("win_rate")
plt.plot(np.cumsum(wininig_DQN) / (np.arange(len(wininig_DQN)) + 1))


#recordを訓練用に復帰
enemy_dqn_player.record = train_record
enemy_dqn_player.eps = train_eps
enemy_dqn_player.memory = train_memory
